# %%
import cv2 as cv2
import numpy as np

img = cv2.imread('../BaseDatosNISTsd09_pr/crd_0813f/crd_0813f_01.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

thr = cv2.adaptiveThreshold(gray, 200, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 10)

cv2.imwrite('ejemplo__keypoints.png', img_with_keypoints)
# Mostrar la imagen con puntos clave
#plt.imshow(cv2.cvtColor(img_with_keypoints, cv2.COLOR_BGR2RGB))
plt.imshow(cv2.cvtColor(thr, cv2.COLOR_BGR2RGB))
plt.title('Puntos')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       7 thr = cv2.adaptiveThreshold(gray, 200, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 10)
# ----> 9 cv2.imwrite('ejemplo__keypoints.png', img_with_keypoints)
#      10 # Mostrar la imagen con puntos clave
#      11 #plt.imshow(cv2.cvtColor(img_with_keypoints, cv2.COLOR_BGR2RGB))
#      12 plt.imshow(cv2.cvtColor(thr, cv2.COLOR_BGR2RGB))
#
# NameError: name 'img_with_keypoints' is not defined
