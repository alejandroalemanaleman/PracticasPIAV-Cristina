# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt

# %%
#muestra que se quiere comparar

sample_path = r"\BaseDatosNISTsd09_pr"
sample_path = os.getcwd()+sample_path
files= os.listdir(sample_path)

# Busca en el directorio a cada uno de los sujetos
counter=0 
print(files)
for file in files:
    dir = sample_path +'\\'
    dir = dir + file + '\\'
    file2= os.listdir(dir)
    ruta=dir+'\\'+file2[0]
    sample = cv.imread(ruta) #muestras para tomar de referencia
    counter+=1
    #segundo bucle para comparar con todas
    for file in files:
        dir = sample_path +'\\'
        dir = dir + file + '\\'
        file2= os.listdir(dir)
        ruta=dir+'\\'+file2[1] 
        sample2 = cv.imread(ruta) #muestras para tomar de referencia
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 #muestra que se quiere comparar
#       3 sample_path = r"\BaseDatosNISTsd09_pr"
# ----> 4 sample_path = os.getcwd()+sample_path
#       5 files= os.listdir(sample_path)
#       7 # Busca en el directorio a cada uno de los sujetos
#
# NameError: name 'os' is not defined

# %% [markdown]
# A partir de la base de datos proporcionada, se realizarÃ¡ un programa que permita identificar las huellas del mismo usuario y descartar el resto, dando informaciÃ³n cuantitativa de la similitud entre las huellas, pudiendo utilizar openCV, numpy, os, PyTorch,..., pero no funciones descargadas especialmente para trabajar con huellas dactilares.
#
# Se obtendrÃ¡ la funciÃ³n densidad de probabilidad, la curva DET, la curva ROC., el valor EER y el valor AUC.
#
# Se realizarÃ¡ un pÃ³ster (una Ãºnica transparencia) y se presentarÃ¡ durante la Ãºltima semana de clase. AdemÃ¡s, se entregarÃ¡ el cÃ³digo usado.
#
# En la presentaciÃ³n tienen que tratarse los siguientes puntos:
#
# -HipÃ³tesis de partida.
# -MetodologÃ­a utilizada y explicaciÃ³n de su desarrollo.
# -Resultados (curvas, EER y AUC).
# -Conclusiones.
# -Fuentes principales consultadas.
