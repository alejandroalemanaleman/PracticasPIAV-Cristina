# %%
import numpy as np
import cv2

#frame= cv2.VideoCapture(0)
frame = cv2.VideoCapture("videos/people2.mp4")


# crea colores aleatorios
color = np.random.randint(0,255,(100,3))

# toma la primera imagen
status, old_frame = frame.read()
old_gray = cv2.cvtColor(old_frame, cv2.COLOR_BGR2GRAY)


#inicializo una imagen para aÃ±adir los resultados en blanco
result2 =  np.zeros_like(old_gray)
int = 0
while status:

        #captura la imagen 2
        ret, img = frame.read()
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      
        #calcula la diferencia
        result =  gray - old_gray
        result[result<50]= 255
        result2 = result + result2
        result2[result2>250] = 255
        if int> 20:
          cv2.imshow('foto',result2)
          result2 =  255*np.ones_like(old_gray) 
          int = 0  
    
        cv2.imshow('frame', result2)
        # actualiza la imagen 1
        old_gray = gray.copy()
        if cv2.waitKey(1)==27:
            status = False   
        int +=1
            
    
frame.release()
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 23
#      19 while status:
#      20
#      21         #captura la imagen 2
#      22         ret, img = frame.read()
# ---> 23         gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      25         #calcula la diferencia
#      26         result =  gray - old_gray
#
# error: OpenCV(4.8.1) /Users/xperience/GHA-OpenCV-Python/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
